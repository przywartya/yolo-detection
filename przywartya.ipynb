# %%
from evaluate import start_eval

# %%
# Run evaluation on validation dataset.
# For each ground truth bbox it tries to find a matching predicted bounding box.
# Finally prints the precision of detected boxes (iou with ground truth).
# Also prints how many faces was it able to find out of all faces in the dataset.
# Accuracy 76%, found 131 out of 137 faces.
start_eval()
# Out:
# Using TensorFlow backend.
#   1%|          | 1/108 [00:03<05:56,  3.33s/it]
# Success matching [[ 892  241 1034  366]] [[ 894  245 1019  369]]
#   2%|▏         | 2/108 [00:05<04:43,  2.68s/it]
# Success matching [[280 180 381 268]] [[294 189 381 275]]
#   3%|▎         | 3/108 [00:07<04:18,  2.46s/it]
# Success matching [[254  65 377 217]] [[244  62 394 211]]
#   4%|▎         | 4/108 [00:09<04:04,  2.36s/it]
# Success matching [[227  38 282  87]] [[213  29 285 101]]
#   5%|▍         | 5/108 [00:11<03:56,  2.30s/it]
# Success matching [[550 134 661 243]] [[561 146 664 250]]
# Success matching [[333  82 476 190]] [[342  79 466 203]]
#   6%|▌         | 6/108 [00:13<03:50,  2.26s/it]
# Success matching [[373  83 903 512]] [[445 115 816 486]]
#   6%|▋         | 7/108 [00:15<03:45,  2.24s/it]
# Success matching [[402  22 497 152]] [[400  31 503 135]]
#   7%|▋         | 8/108 [00:17<03:42,  2.22s/it]
# Success matching [[ 74  58 158 155]] [[ 74  64 160 150]]
# ...

# %%
# Load yolo and the classifier from previous project.
from yolo3 import yolo_model
from keras.models import load_model
yolo = yolo_model.YOLO('przywartya.h5')
classifier = load_model('recognition.h5', compile=False)

# %%
from pipeline import pipe_the_image
# Let's run the full pipeline.

# %%
pipe_the_image("dataset/taco_hemingway/237.jpg", classifier, yolo)
# Out:
# 49 70 150 178
# (363, 602, 3)

# %%
pipe_the_image("dataset/taco_hemingway/223.jpg", classifier, yolo)
# Out:
# 285 62 371 130
# (262, 620, 3)

# %%
pipe_the_image("dataset/taco_hemingway/234.jpg", classifier, yolo)
# Out:
# 564 666 746 840
# (960, 960, 3)
# 165 242 406 479
# (960, 960, 3)
# 583 276 782 502
# (960, 960, 3)
# 295 654 425 762
# (960, 960, 3)

# %%
pipe_the_image("dataset/taco_hemingway/216.jpg", classifier, yolo)
# Out:
# 446 73 525 155
# (660, 1500, 3)
# 791 34 1417 583
# (660, 1500, 3)

# %%
pipe_the_image("dataset/taco_hemingway/214.jpg", classifier, yolo) # detects the drawing even though it is so small!
# Out:
# 419 345 458 379
# (666, 1000, 3)
# 428 92 560 231
# (666, 1000, 3)

# %%
pipe_the_image("dataset/taco_hemingway/212.jpg", classifier, yolo)
# Out:
# 302 58 382 153
# (450, 800, 3)

# %%
pipe_the_image("dataset/taco_hemingway/201.jpg", classifier, yolo)
# Out:
# 249 81 381 217
# (363, 602, 3)

# %%
pipe_the_image("dataset/otsochodzi/201.jpg", classifier, yolo)
# Out:
# 230 223 387 422
# (675, 1279, 3)

# %%
pipe_the_image("dataset/otsochodzi/13.jpg", classifier, yolo)
# Out:
# 223 13 412 176
# (400, 742, 3)

# %%
pipe_the_image("dataset/otsochodzi/75.jpg", classifier, yolo)
# Out:
# 133 99 246 208
# (363, 602, 3)

# %%
pipe_the_image("dataset/otsochodzi/172.png", classifier, yolo)
# Out:
# 165 144 190 178
# (220, 300, 4)
# 120 27 183 92
# (220, 300, 4)

# %%
pipe_the_image("dataset/otsochodzi/403.jpg", classifier, yolo)
# Out:
# 129 48 199 123
# (300, 620, 3)
# 409 59 572 237
# (300, 620, 3)

# %%
pipe_the_image("dataset/otsochodzi/244.png", classifier, yolo)
# Out:
# 261 29 463 251
# (400, 750, 4)

# %%
pipe_the_image("dataset/ostr/23.jpg", classifier, yolo)
# Out:
# 6 9 521 539
# (994, 560, 3)

# %%
pipe_the_image("dataset/ostr/26.jpg", classifier, yolo)
# Out:
# 436 78 545 205
# (640, 960, 3)

# %%
pipe_the_image("dataset/ostr/357.jpg", classifier, yolo)
# Out:
# 1171 347 1262 398
# (720, 1280, 3)
# 1098 229 1192 308
# (720, 1280, 3)
# 617 48 903 335
# (720, 1280, 3)

# %%
pipe_the_image("dataset/ostr/35.jpg", classifier, yolo)
# Out:
# 264 129 504 375
# (481, 972, 3)

# %%
pipe_the_image("dataset/ostr/89.jpg", classifier, yolo)
# Out:
# 139 105 212 165
# (281, 500, 3)
# 217 31 290 104
# (281, 500, 3)

# %%
pipe_the_image("dataset/keke/58.jpg", classifier, yolo)
# Out:
# 565 58 830 236
# (1001, 1581, 3)
# 1151 526 1311 662
# (1001, 1581, 3)
# 700 580 905 812
# (1001, 1581, 3)
# 165 170 346 396
# (1001, 1581, 3)
# 171 606 363 807
# (1001, 1581, 3)
# 1205 97 1392 269
# (1001, 1581, 3)

# %%
pipe_the_image("dataset/keke/84.jpg", classifier, yolo)
# Out:
# 342 51 412 120
# (363, 602, 3)
# 463 47 545 122
# (363, 602, 3)
# 46 70 193 222
# (363, 602, 3)

# %%
pipe_the_image("dataset/keke/447.jpg", classifier, yolo)
# Out:
# 222 245 282 315
# (1080, 1080, 3)
# 570 584 953 932
# (1080, 1080, 3)
# 124 527 271 644
# (1080, 1080, 3)
